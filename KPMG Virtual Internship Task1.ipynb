# %%
import pandas as pd

# %% [markdown]
# ## Reading Data Set

# %%
df_trans = pd.read_excel(r'C:/Users/DELL/Desktop/Virtual Internship/KPMG Virtual Internship/KPMG_VI_New_raw_data_update_final.xlsx',skiprows=[0],engine='openpyxl', sheet_name='Transactions',usecols = "A:M")
df_demo = pd.read_excel(r'C:/Users/DELL/Desktop/Virtual Internship/KPMG Virtual Internship/KPMG_VI_New_raw_data_update_final.xlsx',skiprows=[0],engine='openpyxl', sheet_name='CustomerDemographic',usecols = "A:M")
df_addr = pd.read_excel(r'C:/Users/DELL/Desktop/Virtual Internship/KPMG Virtual Internship/KPMG_VI_New_raw_data_update_final.xlsx',skiprows=[0],engine='openpyxl', sheet_name='CustomerAddress',usecols = "A:F")

# %% [markdown]
# ### Printing Transaction DataSet

# %%
df_trans.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
df_trans.count()
# Out:
# transaction_id             20000
# product_id                 20000
# customer_id                20000
# transaction_date           20000
# online_order               19640
# order_status               20000
# brand                      19803
# product_line               19803
# product_class              19803
# product_size               19803
# list_price                 20000
# standard_cost              19803
# product_first_sold_date    19803
# dtype: int64

# %% [markdown]
# ### Printing Customer Demographic DataSet

# %%
df_demo.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
df_demo.count()
# Out:
# customer_id                            4000
# first_name                             4000
# last_name                              3875
# gender                                 4000
# past_3_years_bike_related_purchases    4000
# DOB                                    3913
# job_title                              3494
# job_industry_category                  3344
# wealth_segment                         4000
# deceased_indicator                     4000
# default                                3698
# owns_car                               4000
# tenure                                 3913
# dtype: int64

# %% [markdown]
# ### Printing Customer Address DataSet

# %%
df_addr.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %% [markdown]
# ### First Analysing Customer Transaction DataSet

# %%
df_trans[df_trans.duplicated()]
# Out:
# Empty DataFrame
# Columns: [transaction_id, product_id, customer_id, transaction_date, online_order, order_status, brand, product_line, product_class, product_size, list_price, standard_cost, product_first_sold_date]
# Index: []

# %%
df_trans.dtypes
# Out:
# transaction_id                      int64
# product_id                          int64
# customer_id                         int64
# transaction_date           datetime64[ns]
# online_order                      float64
# order_status                       object
# brand                              object
# product_line                       object
# product_class                      object
# product_size                       object
# list_price                        float64
# standard_cost                     float64
# product_first_sold_date           float64
# dtype: object

# %%
df_trans.sort_values(by='transaction_date').head(2)
# Out:
#       transaction_id  product_id  customer_id transaction_date  online_order  \
# 516              517          77          311       2017-01-01           1.0
# 5876            5877          67          138       2017-01-01           0.0
#
#      order_status           brand product_line product_class product_size  \
# 516      Approved        WeareA2B     Standard        medium       medium
# 5876     Approved  Norco Bicycles         Road        medium       medium
#
#       list_price  standard_cost  product_first_sold_date
# 516      1769.64         108.76                  40672.0
# 5876      544.05         376.84                  38647.0

# %%
df_trans.sort_values(by='transaction_date',ascending=False).head(2)
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 1696             1697          56         2421       2017-12-30           1.0
# 15269           15270           3          195       2017-12-30           0.0
#
#       order_status          brand product_line product_class product_size  \
# 1696      Approved     OHM Cycles     Standard        medium       medium
# 15269     Approved  Trek Bicycles     Standard        medium        large
#
#        list_price  standard_cost  product_first_sold_date
# 1696       183.86         137.90                  33259.0
# 15269     2091.47         388.92                  41167.0

# %%
df_trans[df_trans.isnull().any(axis=1)].head(3)
#total 555 rows
# Out:
#      transaction_id  product_id  customer_id transaction_date  online_order  \
# 97               98          49          333       2017-06-23           NaN
# 136             137           0          431       2017-09-23           0.0
# 159             160           0         3300       2017-08-27           0.0
#
#     order_status          brand product_line product_class product_size  \
# 97      Approved  Trek Bicycles         Road        medium       medium
# 136     Approved            NaN          NaN           NaN          NaN
# 159     Approved            NaN          NaN           NaN          NaN
#
#      list_price  standard_cost  product_first_sold_date
# 97       533.51         400.13                  37823.0
# 136     1942.61            NaN                      NaN
# 159     1656.86            NaN                      NaN

# %%
df_trans[df_trans.duplicated(subset='transaction_id', keep='first')]
#df_trans[df_trans.duplicated(subset='product_line', keep='first')]
# Out:
# Empty DataFrame
# Columns: [transaction_id, product_id, customer_id, transaction_date, online_order, order_status, brand, product_line, product_class, product_size, list_price, standard_cost, product_first_sold_date]
# Index: []

# %%
df_trans[df_trans['brand'].isnull()].head(3)
#df_trans[df_trans['transaction_id'].isnull()].head(3)
# Out:
#      transaction_id  product_id  customer_id transaction_date  online_order  \
# 136             137           0          431       2017-09-23           0.0
# 159             160           0         3300       2017-08-27           0.0
# 366             367           0         1614       2017-03-10           0.0
#
#     order_status brand product_line product_class product_size  list_price  \
# 136     Approved   NaN          NaN           NaN          NaN     1942.61
# 159     Approved   NaN          NaN           NaN          NaN     1656.86
# 366     Approved   NaN          NaN           NaN          NaN      850.89
#
#      standard_cost  product_first_sold_date
# 136            NaN                      NaN
# 159            NaN                      NaN
# 366            NaN                      NaN

# %%
df_demo[df_demo.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, default, owns_car, tenure]
# Index: []

# %%
df_demo.sort_values(by='DOB',ascending=False).head(2)
# Out:
#       customer_id first_name last_name  gender  \
# 65             66     Anselm     Gawne    Male
# 1887         1888      Sibyl   Scholtz  Female
#
#       past_3_years_bike_related_purchases        DOB          job_title  \
# 65                                     46 2002-03-11  Account Executive
# 1887                                   67 2002-01-26       Food Chemist
#
#      job_industry_category  wealth_segment deceased_indicator        default  \
# 65             Argiculture  High Net Worth                  N  ï½ï½¨(Â´âï½â©
# 1887                Health   Mass Customer                  N            NaN
#
#      owns_car  tenure
# 65         No     1.0
# 1887      Yes     1.0

# %%
df_demo.sort_values(by='DOB').head(2)
# Out:
#      customer_id first_name last_name gender  \
# 33            34   Jephthah  Bachmann      U
# 719          720     Darrel     Canet   Male
#
#      past_3_years_bike_related_purchases        DOB           job_title  \
# 33                                    59 1843-12-21     Legal Assistant
# 719                                   67 1931-10-23  Recruiting Manager
#
#     job_industry_category     wealth_segment deceased_indicator  \
# 33                     IT  Affluent Customer                  N
# 719                Retail  Affluent Customer                  N
#
#                 default owns_car  tenure
# 33                  NaN       No    20.0
# 719  1;DROP TABLE users       No     6.0

# %%
len(df_demo[df_demo['DOB'].isnull()])
# Out:
# 87

# %%
df_demo['gender'].unique()
# Out:
# array(['F', 'Male', 'Female', 'U', 'Femal', 'M'], dtype=object)

# %%
df_demo.drop_duplicates(subset=['customer_id'], keep='first').head(2)
# Out:
#    customer_id first_name  last_name gender  \
# 0            1    Laraine  Medendorp      F
# 1            2        Eli    Bockman   Male
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
#
#   job_industry_category wealth_segment deceased_indicator  \
# 0                Health  Mass Customer                  N
# 1    Financial Services  Mass Customer                  N
#
#                         default owns_car  tenure
# 0                            "'      Yes    11.0
# 1  <script>alert('hi')</script>      Yes    16.0

# %%
df_demo.dtypes
# Out:
# customer_id                                     int64
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int64
# DOB                                    datetime64[ns]
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# default                                        object
# owns_car                                       object
# tenure                                        float64
# dtype: object

# %%
df_demo[df_demo.isnull().any(axis=1)].head(3)
# Out:
#    customer_id      first_name  last_name  gender  \
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
# 5            6            Curr  Duckhouse    Male
#
#    past_3_years_bike_related_purchases        DOB      job_title  \
# 3                                   33 1961-10-03            NaN
# 4                                   56 1977-05-13  Senior Editor
# 5                                   35 1966-09-16            NaN
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 3                    IT      Mass Customer                  N
# 4                   NaN  Affluent Customer                  N
# 5                Retail     High Net Worth                  N
#
#                                              default owns_car  tenure
# 3  () { _; } >_[$($())] { touch /tmp/blns.shellsh...       No     7.0
# 4                                                NIL      Yes     8.0
# ...

# %%
df_addr[df_addr.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, address, postcode, state, country, property_valuation]
# Index: []

# %%
df_addr.dtypes
# Out:
# customer_id            int64
# address               object
# postcode               int64
# state                 object
# country               object
# property_valuation     int64
# dtype: object

# %%
df_addr[df_addr.isnull().any(axis=1)].head(3)
# Out:
# Empty DataFrame
# Columns: [customer_id, address, postcode, state, country, property_valuation]
# Index: []

# %%
df_addr[df_addr.duplicated(subset='postcode')].head(2)
# Out:
#     customer_id           address  postcode            state    country  \
# 18           21   18 Jenna Center      2650  New South Wales  Australia
# 19           24  3 Cordelia Plaza      2153  New South Wales  Australia
#
#     property_valuation
# 18                   7
# 19                  10

# %%
df_addr[df_addr['customer_id'].isnull()].head(3)
# Out:
# Empty DataFrame
# Columns: [customer_id, address, postcode, state, country, property_valuation]
# Index: []

# %%
df_addr[df_addr['postcode']==2650].head(2)
# Out:
#     customer_id              address  postcode            state    country  \
# 6             8  49 Londonderry Lane      2650  New South Wales  Australia
# 18           21      18 Jenna Center      2650  New South Wales  Australia
#
#     property_valuation
# 6                    4
# 18                   7

# %%
df_addr['state'].unique()
# Out:
# array(['New South Wales', 'QLD', 'VIC', 'NSW', 'Victoria'], dtype=object)
